# %%
import pandas as pd
b0=pd.read_csv("file0.csv")
b0
# Out:
#                           _id                          Tipo  \
# 0    6581ffbe7d4586d80596ab2c            Habitación privada
# 1    6581ffbe7d4586d80596ab2d            Habitación privada
# 2    6581ffbe7d4586d80596ab2e            Habitación privada
# 3    6581ffbe7d4586d80596ab2f            Habitación privada
# 4    6581ffbe7d4586d80596ab30      Alojamiento entero: piso
# ..                        ...                           ...
# 194  6581ffbe7d4586d80596abee      Alojamiento entero: piso
# 195  6581ffbe7d4586d80596abef            Habitación privada
# 196  6581ffbe7d4586d80596abf0  Habitación de hotel boutique
# 197  6581ffbe7d4586d80596abf1           Habitación de hotel
# 198  6581ffbe7d4586d80596abf2            Habitación privada
#
#                                      nombreAlojamiento  \
# 0      Habitacion centro Barcelona, Ciutat Vella room.
# 1    Agradable habitación en pleno centro de Barcelona
# 2     Room in the city center (Gothic,Rambla,Catedral)
# ...

# %%
import json
import pandas as pd
with open('file1.json', encoding='utf-8') as data:
    file1 = json.load(data)
df = pd.DataFrame(file1)
df.to_csv('file1.csv', index=False)
b1 = pd.read_csv("file1.csv")
b1
# Out:
#                           _id                          Tipo  \
# 0    6581ffbe7d4586d80596abf3      Alojamiento entero: piso
# 1    6581ffbe7d4586d80596abf4  Habitación de hotel boutique
# 2    6581ffbe7d4586d80596abf5            Habitación privada
# 3    6581ffbe7d4586d80596abf6            Habitación privada
# 4    6581ffbe7d4586d80596abf7      Alojamiento entero: piso
# ..                        ...                           ...
# 194  6581ffbe7d4586d80596acb5      Alojamiento entero: piso
# 195  6581ffbe7d4586d80596acb6            Habitación privada
# 196  6581ffbe7d4586d80596acb7            Habitación privada
# 197  6581ffbe7d4586d80596acb8            Habitación privada
# 198  6581ffbe7d4586d80596acb9            Habitación privada
#
#                                      nombreAlojamiento  \
# 0    Barcelona Marta´s Flat 2 - FC Barcelona HUTB01...
# 1     Habitación Doble Exterior, baño privado y balcón
# 2                  Luxury room with private bathroom 2
# ...

# %%
list1 = pd.concat([b0,b1])
list1
list1.to_csv('list1.csv')

# %%
import sqlite3 
import pandas as pd
con = sqlite3.connect("file3.db")
df = pd.read_sql_query("SELECT * FROM file2", con)
df.to_csv("file2.csv")
b2 = pd.read_csv("file2.csv")
b2
# Out:
#      Unnamed: 0                    field1                    field2  \
# 0             0                       _id                      Tipo
# 1             1  6581ffbe7d4586d80596acba        Habitación privada
# 2             2  6581ffbe7d4586d80596acbb  Alojamiento entero: loft
# 3             3  6581ffbe7d4586d80596acbc        Habitación privada
# 4             4  6581ffbe7d4586d80596acbd        Habitación privada
# ..          ...                       ...                       ...
# 195         195  6581ffbe7d4586d80596ad7c        Habitación privada
# 196         196  6581ffbe7d4586d80596ad7d       Habitación de hotel
# 197         197  6581ffbe7d4586d80596ad7e        Habitación privada
# 198         198  6581ffbe7d4586d80596ad7f        Habitación privada
# 199         199  6581ffbe7d4586d80596ad80  Alojamiento entero: piso
#
#                                              field3  \
# 0                                 nombreAlojamiento
# ...

# %%
import sqlite3 
import pandas as pd
con = sqlite3.connect("file3.db")
df = pd.read_sql_query("SELECT * FROM file3", con)
df.to_csv("file3.csv")
b3 = pd.read_csv("file3.csv")
b3
# Out:
#      Unnamed: 0                    field1                    field2  \
# 0             0                       _id                      Tipo
# 1             1  6581ffbe7d4586d80596ad81        Habitación privada
# 2             2  6581ffbe7d4586d80596ad82        Habitación privada
# 3             3  6581ffbe7d4586d80596ad83  Alojamiento entero: piso
# 4             4  6581ffbe7d4586d80596ad84        Habitación privada
# ..          ...                       ...                       ...
# 100         100  6581ffbe7d4586d80596ade4        Habitación privada
# 101         101  6581ffbe7d4586d80596ade5        Habitación privada
# 102         102  6581ffbe7d4586d80596ade6  Alojamiento entero: piso
# 103         103  6581ffbe7d4586d80596ade7        Habitación privada
# 104         104  6581ffbe7d4586d80596ade8        Habitación privada
#
#                                                 field3  \
# 0                                    nombreAlojamiento
# ...

# %%
list2 = pd.concat([b2,b3])
list2
list2.to_csv('list2.csv')

# %%
list1=pd.read_csv("list1.csv")
list2=pd.read_csv("list2.csv")
lista_general = pd.concat([list1,list2])
lista_general
lista_general.to_csv('lista_general.csv')

# %%
lista_general = pd.read_csv("lista_general.csv")
lista_general
# Out:
#      Unnamed: 0.2  Unnamed: 0                       _id  \
# 0               0           0  6581ffbe7d4586d80596ab2c
# 1               1           1  6581ffbe7d4586d80596ab2d
# 2               2           2  6581ffbe7d4586d80596ab2e
# 3               3           3  6581ffbe7d4586d80596ab2f
# 4               4           4  6581ffbe7d4586d80596ab30
# ..            ...         ...                       ...
# 698           300         100                       NaN
# 699           301         101                       NaN
# 700           302         102                       NaN
# 701           303         103                       NaN
# 702           304         104                       NaN
#
#                          Tipo  \
# 0          Habitación privada
# 1          Habitación privada
# 2          Habitación privada
# 3          Habitación privada
# 4    Alojamiento entero: piso
# ..                        ...
# 698                       NaN
# 699                       NaN
# ...

# %%
lista_general[(lista_general['Valoracion'] == 3.5)]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.2, Unnamed: 0, _id, Tipo, nombreAlojamiento, Zona, Nhab, Servicios, Fechas, Valoracion, Evaluaciones, Noche, Total, Unnamed: 0.1, field1, field2, field3, field4, field5, field6, field7, field8, field9, field10, field11]
# Index: []
#
# [0 rows x 25 columns]

# %%
lista_general[(lista_general['Servicios'] =='Wifi')]
# Out:
#      Unnamed: 0.2  Unnamed: 0                       _id                  Tipo  \
# 6               6           6  6581ffbe7d4586d80596ab32    Habitación privada
# 9               9           9  6581ffbe7d4586d80596ab35    Habitación privada
# 15             15          15  6581ffbe7d4586d80596ab3b    Habitación privada
# 16             16          16  6581ffbe7d4586d80596ab3c    Habitación privada
# 21             21          21  6581ffbe7d4586d80596ab41    Habitación privada
# 23             23          23  6581ffbe7d4586d80596ab43  Habitación de hostal
# 27             27          27  6581ffbe7d4586d80596ab47    Habitación privada
# 32             32          32  6581ffbe7d4586d80596ab4c    Habitación privada
# 36             36          36  6581ffbe7d4586d80596ab50    Habitación privada
# 42             42          42  6581ffbe7d4586d80596ab56    Habitación privada
# 44             44          44  6581ffbe7d4586d80596ab58    Habitación privada
# ...

# %%
lista_general[(lista_general['Servicios'] =='Cocina')]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.2, Unnamed: 0, _id, Tipo, nombreAlojamiento, Zona, Nhab, Servicios, Fechas, Valoracion, Evaluaciones, Noche, Total, Unnamed: 0.1, field1, field2, field3, field4, field5, field6, field7, field8, field9, field10, field11]
# Index: []
#
# [0 rows x 25 columns]

# %%
lista_general[(lista_general['Evaluaciones'] == 50)]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.2, Unnamed: 0, _id, Tipo, nombreAlojamiento, Zona, Nhab, Servicios, Fechas, Valoracion, Evaluaciones, Noche, Total, Unnamed: 0.1, field1, field2, field3, field4, field5, field6, field7, field8, field9, field10, field11]
# Index: []
#
# [0 rows x 25 columns]

# %%
lista_general[(lista_general['Zona'] == "Ciutat Vella")]
# Out:
#      Unnamed: 0.2  Unnamed: 0                       _id  \
# 0               0           0  6581ffbe7d4586d80596ab2c
# 2               2           2  6581ffbe7d4586d80596ab2e
# 4               4           4  6581ffbe7d4586d80596ab30
# 10             10          10  6581ffbe7d4586d80596ab36
# 11             11          11  6581ffbe7d4586d80596ab37
# ..            ...         ...                       ...
# 382           382         183  6581ffbe7d4586d80596acaa
# 383           383         184  6581ffbe7d4586d80596acab
# 386           386         187  6581ffbe7d4586d80596acae
# 389           389         190  6581ffbe7d4586d80596acb1
# 390           390         191  6581ffbe7d4586d80596acb2
#
#                          Tipo  \
# 0          Habitación privada
# 2          Habitación privada
# 4    Alojamiento entero: piso
# 10       Habitación de hostal
# 11         Habitación privada
# ..                        ...
# 382        Habitación privada
# 383        Habitación privada
# ...

# %%
lista_general[(lista_general['Servicios'] == "Aire acondicionado")&(lista_general['Noche'] == 25)]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.2, Unnamed: 0, _id, Tipo, nombreAlojamiento, Zona, Nhab, Servicios, Fechas, Valoracion, Evaluaciones, Noche, Total, Unnamed: 0.1, field1, field2, field3, field4, field5, field6, field7, field8, field9, field10, field11]
# Index: []
#
# [0 rows x 25 columns]

# %%
lista_general[(lista_general['Servicios'] == "Wifi")|(lista_general['Evaluaciones'] == 20)]
# Out:
#      Unnamed: 0.2  Unnamed: 0                       _id                  Tipo  \
# 6               6           6  6581ffbe7d4586d80596ab32    Habitación privada
# 9               9           9  6581ffbe7d4586d80596ab35    Habitación privada
# 15             15          15  6581ffbe7d4586d80596ab3b    Habitación privada
# 16             16          16  6581ffbe7d4586d80596ab3c    Habitación privada
# 21             21          21  6581ffbe7d4586d80596ab41    Habitación privada
# 23             23          23  6581ffbe7d4586d80596ab43  Habitación de hostal
# 27             27          27  6581ffbe7d4586d80596ab47    Habitación privada
# 32             32          32  6581ffbe7d4586d80596ab4c    Habitación privada
# 36             36          36  6581ffbe7d4586d80596ab50    Habitación privada
# 42             42          42  6581ffbe7d4586d80596ab56    Habitación privada
# 44             44          44  6581ffbe7d4586d80596ab58    Habitación privada
# ...

# %%
lista_general[(lista_general['Servicios'] == "Ciutat Vella")&(lista_general['Evaluaciones'] == 50)]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.2, Unnamed: 0, _id, Tipo, nombreAlojamiento, Zona, Nhab, Servicios, Fechas, Valoracion, Evaluaciones, Noche, Total, Unnamed: 0.1, field1, field2, field3, field4, field5, field6, field7, field8, field9, field10, field11]
# Index: []
#
# [0 rows x 25 columns]

# %%
lista_general[(lista_general['Tipo'] == "Habitación privada")|(lista_general['Valoracion'] == 3)]
# Out:
#      Unnamed: 0.2  Unnamed: 0                       _id                Tipo  \
# 0               0           0  6581ffbe7d4586d80596ab2c  Habitación privada
# 1               1           1  6581ffbe7d4586d80596ab2d  Habitación privada
# 2               2           2  6581ffbe7d4586d80596ab2e  Habitación privada
# 3               3           3  6581ffbe7d4586d80596ab2f  Habitación privada
# 5               5           5  6581ffbe7d4586d80596ab31  Habitación privada
# ..            ...         ...                       ...                 ...
# 392           392         193  6581ffbe7d4586d80596acb4  Habitación privada
# 394           394         195  6581ffbe7d4586d80596acb6  Habitación privada
# 395           395         196  6581ffbe7d4586d80596acb7  Habitación privada
# 396           396         197  6581ffbe7d4586d80596acb8  Habitación privada
# 397           397         198  6581ffbe7d4586d80596acb9  Habitación privada
#
# ...

# %%
lista_general[(lista_general['Servicios'] == "Cocina")&(lista_general['Valoracion'] == 2.5)]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.2, Unnamed: 0, _id, Tipo, nombreAlojamiento, Zona, Nhab, Servicios, Fechas, Valoracion, Evaluaciones, Noche, Total, Unnamed: 0.1, field1, field2, field3, field4, field5, field6, field7, field8, field9, field10, field11]
# Index: []
#
# [0 rows x 25 columns]
