# %%
import pymongo
import pandas as pd
from pymongo import MongoClient

# Conexión al servidor de MongoDB
client = MongoClient('localhost:27017')

# Selección de la base de datos y la colección
db = client.canciones
collection = db.canciones

# Conversión de los datos de la colección a un DataFrame de pandas
data = pd.DataFrame(list(collection.find()))

#Lectrura de la base
data
# Out:
#                           _id                           track_name  \
# 0    6585f9d46bef7b3db50d693d  Seven (feat. Latto) (Explicit Ver.)
# 1    6585f9d46bef7b3db50d693e                                 LALA
# 2    6585f9d46bef7b3db50d693f                              vampire
# 3    6585f9d46bef7b3db50d6940                         Cruel Summer
# 4    6585f9d46bef7b3db50d6941                       WHERE SHE GOES
# ..                        ...                                  ...
# 948  6585f9d46bef7b3db50d6cf1                         My Mind & Me
# 949  6585f9d46bef7b3db50d6cf2            Bigger Than The Whole Sky
# 950  6585f9d46bef7b3db50d6cf3                 A Veces (feat. Feid)
# 951  6585f9d46bef7b3db50d6cf4                        En La De Ella
# 952  6585f9d46bef7b3db50d6cf5                                Alone
#
#          artist(s)_name  artist_count  released_year  released_month  \
# 0      Latto, Jung Kook             2           2023               7
# 1           Myke Towers             1           2023               3
# 2        Olivia Rodrigo             1           2023               6
# 3          Taylor Swift             1           2019               8
# 4             Bad Bunny             1           2023               5
# ..                  ...           ...            ...             ...
# 948        Selena Gomez             1           2022              11
# 949        Taylor Swift             1           2022              10
# 950  Feid, Paulo Londra             2           2022              11
# 951  Feid, Sech, Jhayco             3           2022              10
# 952           Burna Boy             1           2022              11
#
#      released_day  in_spotify_playlists  in_spotify_charts    streams  ...  \
# 0              14                   553                147  141381703  ...
# 1              23                  1474                 48  133716286  ...
# 2              30                  1397                113  140003974  ...
# 3              23                  7858                100  800840817  ...
# 4              18                  3133                 50  303236322  ...
# ..            ...                   ...                ...        ...  ...
# 948             3                   953                  0   91473363  ...
# 949            21                  1180                  0  121871870  ...
# 950             3                   573                  0   73513683  ...
# 951            20                  1320                  0  133895612  ...
# 952             4                   782                  2   96007391  ...
#
#      bpm  key   mode  danceability_% valence_%  energy_% acousticness_%  \
# 0    125    B  Major              80        89        83             31
# 1     92   C#  Major              71        61        74              7
# 2    138    F  Major              51        32        53             17
# 3    170    A  Major              55        58        72             11
# 4    144    A  Minor              65        23        80             14
# ..   ...  ...    ...             ...       ...       ...            ...
# 948  144    A  Major              60        24        39             57
# 949  166   F#  Major              42         7        24             83
# 950   92   C#  Major              80        81        67              4
# 951   97   C#  Major              82        67        77              8
# 952   90    E  Minor              61        32        67             15
#
#     instrumentalness_%  liveness_%  speechiness_%
# 0                    0           8              4
# 1                    0          10              4
# 2                    0          31              6
# 3                    0          11             15
# 4                   63          11              6
# ..                 ...         ...            ...
# 948                  0           8              3
# 949                  1          12              6
# 950                  0           8              6
# 951                  0          12              5
# 952                  0          11              5
#
# [953 rows x 25 columns]
